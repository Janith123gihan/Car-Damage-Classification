# %% [markdown]
# <a href="https://colab.research.google.com/github/Janith123gihan/Car-Damage-Classification/blob/main/Car_Damage_Classification_Transfer_Learning_VGG16_Grayscaleipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import load_img
from tensorflow.keras import layers
import tensorflow as tf
from matplotlib import pyplot as plt
import os
import cv2
import numpy as np
from sklearn.metrics import confusion_matrix
# from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from keras.utils import plot_model
from keras.layers.pooling.global_average_pooling2d import GlobalAveragePooling2D
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Lambda
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
import tensorflow.keras.backend as K
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, LearningRateScheduler

# %%
print(tf.__version__)
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# 2.11.0
# Found GPU at: /device:GPU:0

# %%
def set_data(train,test, validation ,batchSize, image_size):
 
 Image_size = [image_size,image_size]
#  we have to crop the image thatswhy we are using image size

 train_datagen= ImageDataGenerator(rotation_range=10,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.2,rescale=1./255,
                                   zoom_range=0.2,
                                   horizontal_flip=0.5, vertical_flip=0.5
                                   )
#  using image data generator we can perform data aughmentation

 test_datagen = ImageDataGenerator(rescale=1./255) #using image datagenerator we can normalize test images by dividing 255

 val_datagen = ImageDataGenerator(rescale=1./255) #using image datagenerator we can normalize validation images by dividing 255

 #Training dataset
 train_set = train_datagen.flow_from_directory(
                train,
                target_size=Image_size,
                batch_size=batchSize, 
                color_mode='rgb',
                interpolation='bicubic',
                #shuffle=True,             
                class_mode='categorical'
                )
#  in here training data are normalized and aughmentation is performed here
 #Testing dataset
 test_set= test_datagen.flow_from_directory(
              test,
              target_size=Image_size,
              color_mode = 'rgb',interpolation='bicubic',  #Using interpolation='bicubic' in ImageDataGenerator can help improve the quality of the images that are fed into your deep learning model, which can lead to better model performance. 
              class_mode='categorical', shuffle=False
             )
 validation_set = val_datagen.flow_from_directory(
    validation, # same directory as training data
    target_size=Image_size,
    color_mode = 'rgb',interpolation='bicubic',
    batch_size=batchSize)
 return train_set, test_set, validation_set;

# %%
def unfreeze_model(model, num_of_layers):
    for layer in model.layers[num_of_layers:]:
        if not isinstance(layer, layers.BatchNormalization):
            layer.trainable = True
    return model

    # in here layers are unfreezed which means we can manually train some layers in our model after unfreezing layers.

# %% [markdown]
# # Model Creation with vgg16

# %%
base_model = VGG16(weights="imagenet", include_top=False, input_tensor=Input(shape = (224,224,3)))  #classification part is removed thatswhy include_top become false
# base model is created with vgg16 algorithm with size 224x224

head_model = Model(base_model.input, base_model.layers[-2].output) #last two layers are removed because that layers have some layers that are triained for some set of classes in our case we have three classes so we have to modify/add new for it.
head_model.trainable = False #head model is not allowed to train head layers are frozen
head_model = unfreeze_model(head_model,-5)  #last three layers are unfreezed (we can train last three layers of vgg 16 also)

x = head_model.output
# output of the headmodel

se = layers.GlobalAveragePooling2D(name="ch_pool")(x) #global average pooling2d do technique like flatten but that will reduce parameters.
se = layers.Reshape((1,1,512))(se) #layers are reshaped in here input is (None,512) it is reshaped to (1,1,512)
se = layers.Dense(32,activation="swish",kernel_initializer='he_normal', use_bias=False)(se)  #32 dense layers are added with actication function swish 
se = layers.Dense(512,activation="sigmoid",kernel_initializer='he_normal', use_bias=False)(se) #512 dense layers are added with actication function swish 
x = layers.Multiply()([se, x])  #in here this is called channel attention se was multiplied with x 


# The purpose of channel attention is to help the network focus on the most relevant features and ignore the irrelevant ones. 
# It does this by learning a set of weights that are applied to the feature maps to adjust their importance.

x = layers.GlobalAveragePooling2D(name="avg_pool")(x) #global average pooling is added 
x = layers.BatchNormalization()(x) #it will normalize values to one - zero it will help to increase model accuracy.
x = layers.Dropout(0.3)(x) #dropout layer is added.
x = layers.Dense(256, activation="relu",kernel_initializer="orthogonal")(x)  #256 dense layers are added followed by activation funtion relu

x = layers.Dropout(0.6)(x)
x = layers.Dense(128, activation="relu")(x)
x = layers.Dropout(0.3)(x)


outputs = layers.Dense(3, activation="softmax", name="pred")(x) #in here three softmax layers are added becuase we have three classes 
model = tf.keras.Model(head_model.input, outputs) #model type is created
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001) #optimiser is added with learning rate 0.0001
model.compile(optimizer=optimizer, loss="categorical_crossentropy", metrics=["categorical_accuracy"]) #categorical crossentropy is used as loss function and categorical accuracy is use for metrics
model.summary()
plot_model(model,show_shapes=True, show_layer_names=True) #plot model function is used to display model architecture
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 224, 224, 64  1792        ['input_3[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 224, 224, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 112, 112, 64  0           ['block1_conv2[0][0]']
#                                 )
#
#  block2_conv1 (Conv2D)          (None, 112, 112, 12  73856       ['block1_pool[0][0]']
#                                 8)
#
#  block2_conv2 (Conv2D)          (None, 112, 112, 12  147584      ['block2_conv1[0][0]']
#                                 8)
#
#  block2_pool (MaxPooling2D)     (None, 56, 56, 128)  0           ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 56, 56, 256)  295168      ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 56, 56, 256)  590080      ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 56, 56, 256)  590080      ['block3_conv2[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 28, 28, 256)  0           ['block3_conv3[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 28, 28, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 28, 28, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 28, 28, 512)  2359808     ['block4_conv2[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 14, 14, 512)  0           ['block4_conv3[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 14, 14, 512)  2359808     ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 14, 14, 512)  2359808     ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 14, 14, 512)  2359808     ['block5_conv2[0][0]']
#
#  ch_pool (GlobalAveragePooling2  (None, 512)         0           ['block5_conv3[0][0]']
#  D)
#
#  reshape_1 (Reshape)            (None, 1, 1, 512)    0           ['ch_pool[0][0]']
#
#  dense_4 (Dense)                (None, 1, 1, 32)     16384       ['reshape_1[0][0]']
#
#  dense_5 (Dense)                (None, 1, 1, 512)    16384       ['dense_4[0][0]']
#
#  multiply_1 (Multiply)          (None, 14, 14, 512)  0           ['dense_5[0][0]',
#                                                                   'block5_conv3[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 512)         0           ['multiply_1[0][0]']
#  2D)
#
#  batch_normalization_1 (BatchNo  (None, 512)         2048        ['avg_pool[0][0]']
#  rmalization)
#
#  dropout_3 (Dropout)            (None, 512)          0           ['batch_normalization_1[0][0]']
#
#  dense_6 (Dense)                (None, 256)          131328      ['dropout_3[0][0]']
#
#  dropout_4 (Dropout)            (None, 256)          0           ['dense_6[0][0]']
#
#  dense_7 (Dense)                (None, 128)          32896       ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)            (None, 128)          0           ['dense_7[0][0]']
#
#  pred (Dense)                   (None, 3)            387         ['dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 14,914,115
# Trainable params: 9,637,635
# Non-trainable params: 5,276,480
# __________________________________________________________________________________________________

# %%
def plot_hist(hist): #this is a function for plot model accuracy in training time this function will return histogram 
    plt.figure(3)
    plt.plot(hist.history["categorical_accuracy"]) 
    plt.plot(hist.history["val_categorical_accuracy"])

    # categorical accuracy and validation categorical accuracy are plotted in the same graph with title model accuracy and ylabel = accuracy xlabel = epoch
    plt.title("model accuracy")
    plt.ylabel("accuracy")
    plt.xlabel("epoch")
    plt.legend(["train", "validation"], loc="upper left")
    plt.show()
    
    plt.figure(4)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    # in the same graph loss and val_loss are displayed and title is model loss
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
batchSize = 32 #32 batches are used in each epoch 
epoches =80;
image_size = 224;
train_path = '/content/drive/MyDrive/Car Damage Classification/VGG16-Gray/dataset/training'
test_path = '/content/drive/MyDrive/Car Damage Classification/VGG16-Gray/dataset/testing'
validation_path = '/content/drive/MyDrive/Car Damage Classification/VGG16-Gray/dataset/validation'

checkpoint_path = "/content/drive/MyDrive/Car Damage Classification/vgg16/checkpoint.hdf5"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                  monitor='val_categorical_accuracy',mode='max',
                                                save_best_only=True,
                                                verbose=1)



train_set, test_set, validation_set = set_data(train_path,test_path,validation_path, batchSize, image_size)

history=model.fit(train_set,  validation_data= validation_set,epochs = epoches,callbacks=[cp_callback], shuffle=True)
plot_hist(history)
# Out:
# Found 784 images belonging to 3 classes.
# Found 195 images belonging to 3 classes.
# Found 169 images belonging to 3 classes.
# Epoch 1/80
# 25/25 [==============================] - ETA: 0s - loss: 1.0894 - categorical_accuracy: 0.4145
# Epoch 1: val_categorical_accuracy improved from -inf to 0.49704, saving model to /content/drive/MyDrive/Car Damage Classification/vgg16/checkpoint.hdf5
# 25/25 [==============================] - 22s 667ms/step - loss: 1.0894 - categorical_accuracy: 0.4145 - val_loss: 1.0461 - val_categorical_accuracy: 0.4970
# Epoch 2/80
# 25/25 [==============================] - ETA: 0s - loss: 0.9582 - categorical_accuracy: 0.5357
# Epoch 2: val_categorical_accuracy did not improve from 0.49704
# 25/25 [==============================] - 16s 631ms/step - loss: 0.9582 - categorical_accuracy: 0.5357 - val_loss: 0.9667 - val_categorical_accuracy: 0.4497
# Epoch 3/80
# 25/25 [==============================] - ETA: 0s - loss: 0.9385 - categorical_accuracy: 0.5638
# Epoch 3: val_categorical_accuracy did not improve from 0.49704
# 25/25 [==============================] - 14s 569ms/step - loss: 0.9385 - categorical_accuracy: 0.5638 - val_loss: 1.1128 - val_categorical_accuracy: 0.4260
# Epoch 4/80
# 25/25 [==============================] - ETA: 0s - loss: 0.8829 - categorical_accuracy: 0.5944
# Epoch 4: val_categorical_accuracy improved from 0.49704 to 0.59763, saving model to /content/drive/MyDrive/Car Damage Classification/vgg16/checkpoint.hdf5
# 25/25 [==============================] - 16s 638ms/step - loss: 0.8829 - categorical_accuracy: 0.5944 - val_loss: 0.8833 - val_categorical_accuracy: 0.5976
# Epoch 5/80
# 25/25 [==============================] - ETA: 0s - loss: 0.8646 - categorical_accuracy: 0.5867
# Epoch 5: val_categorical_accuracy did not improve from 0.59763
# 25/25 [==============================] - 14s 576ms/step - loss: 0.8646 - categorical_accuracy: 0.5867 - val_loss: 1.0487 - val_categorical_accuracy: 0.5266
# Epoch 6/80
# 25/25 [==============================] - ETA: 0s - loss: 0.8825 - categorical_accuracy: 0.5651
# Epoch 6: val_categorical_accuracy did not improve from 0.59763
# 25/25 [==============================] - 14s 580ms/step - loss: 0.8825 - categorical_accuracy: 0.5651 - val_loss: 0.9006 - val_categorical_accuracy: 0.5089
# Epoch 7/80
# 25/25 [==============================] - ETA: 0s - loss: 0.8343 - categorical_accuracy: 0.6071
# Epoch 7: val_categorical_accuracy did not improve from 0.59763
# 25/25 [==============================] - 14s 567ms/step - loss: 0.8343 - categorical_accuracy: 0.6071 - val_loss: 0.8289 - val_categorical_accuracy: 0.5680
# Epoch 8/80
# 25/25 [==============================] - ETA: 0s - loss: 0.8443 - categorical_accuracy: 0.5931
# Epoch 8: val_categorical_accuracy improved from 0.59763 to 0.63314, saving model to /content/drive/MyDrive/Car Damage Classification/vgg16/checkpoint.hdf5
# 25/25 [==============================] - 16s 637ms/step - loss: 0.8443 - categorical_accuracy: 0.5931 - val_loss: 0.7789 - val_categorical_accuracy: 0.6331
# Epoch 9/80
# 25/25 [==============================] - ETA: 0s - loss: 0.8103 - categorical_accuracy: 0.6097
# Epoch 9: val_categorical_accuracy did not improve from 0.63314
# 25/25 [==============================] - 14s 566ms/step - loss: 0.8103 - categorical_accuracy: 0.6097 - val_loss: 0.8890 - val_categorical_accuracy: 0.4793
# Epoch 10/80
# 25/25 [==============================] - ETA: 0s - loss: 0.8085 - categorical_accuracy: 0.6288
# Epoch 10: val_categorical_accuracy improved from 0.63314 to 0.66864, saving model to /content/drive/MyDrive/Car Damage Classification/vgg16/checkpoint.hdf5
# 25/25 [==============================] - 16s 643ms/step - loss: 0.8085 - categorical_accuracy: 0.6288 - val_loss: 0.7767 - val_categorical_accuracy: 0.6686
# Epoch 11/80
# 25/25 [==============================] - ETA: 0s - loss: 0.7793 - categorical_accuracy: 0.6518
# Epoch 11: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 15s 580ms/step - loss: 0.7793 - categorical_accuracy: 0.6518 - val_loss: 0.8385 - val_categorical_accuracy: 0.6213
# Epoch 12/80
# 25/25 [==============================] - ETA: 0s - loss: 0.8096 - categorical_accuracy: 0.6288
# Epoch 12: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 562ms/step - loss: 0.8096 - categorical_accuracy: 0.6288 - val_loss: 0.9542 - val_categorical_accuracy: 0.6154
# Epoch 13/80
# 25/25 [==============================] - ETA: 0s - loss: 0.7722 - categorical_accuracy: 0.6365
# Epoch 13: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 558ms/step - loss: 0.7722 - categorical_accuracy: 0.6365 - val_loss: 0.9764 - val_categorical_accuracy: 0.5976
# Epoch 14/80
# 25/25 [==============================] - ETA: 0s - loss: 0.7321 - categorical_accuracy: 0.6952
# Epoch 14: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 15s 581ms/step - loss: 0.7321 - categorical_accuracy: 0.6952 - val_loss: 0.7638 - val_categorical_accuracy: 0.6095
# Epoch 15/80
# 25/25 [==============================] - ETA: 0s - loss: 0.7544 - categorical_accuracy: 0.6594
# Epoch 15: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 563ms/step - loss: 0.7544 - categorical_accuracy: 0.6594 - val_loss: 0.8959 - val_categorical_accuracy: 0.5148
# Epoch 16/80
# 25/25 [==============================] - ETA: 0s - loss: 0.7481 - categorical_accuracy: 0.6582
# Epoch 16: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 15s 612ms/step - loss: 0.7481 - categorical_accuracy: 0.6582 - val_loss: 0.9171 - val_categorical_accuracy: 0.5917
# Epoch 17/80
# 25/25 [==============================] - ETA: 0s - loss: 0.6956 - categorical_accuracy: 0.6824
# Epoch 17: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 563ms/step - loss: 0.6956 - categorical_accuracy: 0.6824 - val_loss: 0.8043 - val_categorical_accuracy: 0.5680
# Epoch 18/80
# 25/25 [==============================] - ETA: 0s - loss: 0.7080 - categorical_accuracy: 0.6684
# Epoch 18: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 564ms/step - loss: 0.7080 - categorical_accuracy: 0.6684 - val_loss: 0.8508 - val_categorical_accuracy: 0.5562
# Epoch 19/80
# 25/25 [==============================] - ETA: 0s - loss: 0.6751 - categorical_accuracy: 0.7015
# Epoch 19: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 563ms/step - loss: 0.6751 - categorical_accuracy: 0.7015 - val_loss: 0.8133 - val_categorical_accuracy: 0.6213
# Epoch 20/80
# 25/25 [==============================] - ETA: 0s - loss: 0.6684 - categorical_accuracy: 0.6990
# Epoch 20: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 570ms/step - loss: 0.6684 - categorical_accuracy: 0.6990 - val_loss: 0.8978 - val_categorical_accuracy: 0.5917
# Epoch 21/80
# 25/25 [==============================] - ETA: 0s - loss: 0.6272 - categorical_accuracy: 0.7347
# Epoch 21: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 560ms/step - loss: 0.6272 - categorical_accuracy: 0.7347 - val_loss: 0.7468 - val_categorical_accuracy: 0.6272
# Epoch 22/80
# 25/25 [==============================] - ETA: 0s - loss: 0.5979 - categorical_accuracy: 0.7449
# Epoch 22: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 564ms/step - loss: 0.5979 - categorical_accuracy: 0.7449 - val_loss: 1.5668 - val_categorical_accuracy: 0.3314
# Epoch 23/80
# 25/25 [==============================] - ETA: 0s - loss: 0.5984 - categorical_accuracy: 0.7360
# Epoch 23: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 561ms/step - loss: 0.5984 - categorical_accuracy: 0.7360 - val_loss: 1.0343 - val_categorical_accuracy: 0.5858
# Epoch 24/80
# 25/25 [==============================] - ETA: 0s - loss: 0.5494 - categorical_accuracy: 0.7602
# Epoch 24: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 561ms/step - loss: 0.5494 - categorical_accuracy: 0.7602 - val_loss: 0.8465 - val_categorical_accuracy: 0.6272
# Epoch 25/80
# 25/25 [==============================] - ETA: 0s - loss: 0.5206 - categorical_accuracy: 0.7742
# Epoch 25: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 560ms/step - loss: 0.5206 - categorical_accuracy: 0.7742 - val_loss: 0.8691 - val_categorical_accuracy: 0.6272
# Epoch 26/80
# 25/25 [==============================] - ETA: 0s - loss: 0.5973 - categorical_accuracy: 0.7513
# Epoch 26: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 561ms/step - loss: 0.5973 - categorical_accuracy: 0.7513 - val_loss: 1.8955 - val_categorical_accuracy: 0.5266
# Epoch 27/80
# 25/25 [==============================] - ETA: 0s - loss: 0.5295 - categorical_accuracy: 0.7895
# Epoch 27: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 557ms/step - loss: 0.5295 - categorical_accuracy: 0.7895 - val_loss: 0.8579 - val_categorical_accuracy: 0.6095
# Epoch 28/80
# 25/25 [==============================] - ETA: 0s - loss: 0.4855 - categorical_accuracy: 0.8087
# Epoch 28: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 563ms/step - loss: 0.4855 - categorical_accuracy: 0.8087 - val_loss: 1.4783 - val_categorical_accuracy: 0.4142
# Epoch 29/80
# 25/25 [==============================] - ETA: 0s - loss: 0.4662 - categorical_accuracy: 0.8189
# Epoch 29: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 563ms/step - loss: 0.4662 - categorical_accuracy: 0.8189 - val_loss: 1.0033 - val_categorical_accuracy: 0.6154
# Epoch 30/80
# 25/25 [==============================] - ETA: 0s - loss: 0.4781 - categorical_accuracy: 0.8189
# Epoch 30: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 15s 612ms/step - loss: 0.4781 - categorical_accuracy: 0.8189 - val_loss: 0.8350 - val_categorical_accuracy: 0.5799
# Epoch 31/80
# 25/25 [==============================] - ETA: 0s - loss: 0.4375 - categorical_accuracy: 0.8151
# Epoch 31: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 565ms/step - loss: 0.4375 - categorical_accuracy: 0.8151 - val_loss: 0.9374 - val_categorical_accuracy: 0.6095
# Epoch 32/80
# 25/25 [==============================] - ETA: 0s - loss: 0.4272 - categorical_accuracy: 0.8278
# Epoch 32: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 564ms/step - loss: 0.4272 - categorical_accuracy: 0.8278 - val_loss: 1.1273 - val_categorical_accuracy: 0.5976
# Epoch 33/80
# 25/25 [==============================] - ETA: 0s - loss: 0.4040 - categorical_accuracy: 0.8520
# Epoch 33: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 555ms/step - loss: 0.4040 - categorical_accuracy: 0.8520 - val_loss: 1.0313 - val_categorical_accuracy: 0.5858
# Epoch 34/80
# 25/25 [==============================] - ETA: 0s - loss: 0.3776 - categorical_accuracy: 0.8571
# Epoch 34: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 562ms/step - loss: 0.3776 - categorical_accuracy: 0.8571 - val_loss: 1.0260 - val_categorical_accuracy: 0.5740
# Epoch 35/80
# 25/25 [==============================] - ETA: 0s - loss: 0.3654 - categorical_accuracy: 0.8559
# Epoch 35: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 556ms/step - loss: 0.3654 - categorical_accuracy: 0.8559 - val_loss: 1.3267 - val_categorical_accuracy: 0.6095
# Epoch 36/80
# 25/25 [==============================] - ETA: 0s - loss: 0.3690 - categorical_accuracy: 0.8635
# Epoch 36: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 579ms/step - loss: 0.3690 - categorical_accuracy: 0.8635 - val_loss: 0.9996 - val_categorical_accuracy: 0.5976
# Epoch 37/80
# 25/25 [==============================] - ETA: 0s - loss: 0.3121 - categorical_accuracy: 0.8890
# Epoch 37: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 562ms/step - loss: 0.3121 - categorical_accuracy: 0.8890 - val_loss: 1.0442 - val_categorical_accuracy: 0.6568
# Epoch 38/80
# 25/25 [==============================] - ETA: 0s - loss: 0.3265 - categorical_accuracy: 0.8737
# Epoch 38: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 560ms/step - loss: 0.3265 - categorical_accuracy: 0.8737 - val_loss: 1.0801 - val_categorical_accuracy: 0.6391
# Epoch 39/80
# 25/25 [==============================] - ETA: 0s - loss: 0.4567 - categorical_accuracy: 0.8265
# Epoch 39: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 567ms/step - loss: 0.4567 - categorical_accuracy: 0.8265 - val_loss: 1.2059 - val_categorical_accuracy: 0.6095
# Epoch 40/80
# 25/25 [==============================] - ETA: 0s - loss: 0.3027 - categorical_accuracy: 0.8929
# Epoch 40: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 559ms/step - loss: 0.3027 - categorical_accuracy: 0.8929 - val_loss: 1.7806 - val_categorical_accuracy: 0.5976
# Epoch 41/80
# 25/25 [==============================] - ETA: 0s - loss: 0.2549 - categorical_accuracy: 0.9031
# Epoch 41: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 573ms/step - loss: 0.2549 - categorical_accuracy: 0.9031 - val_loss: 1.7267 - val_categorical_accuracy: 0.5976
# Epoch 42/80
# 25/25 [==============================] - ETA: 0s - loss: 0.3100 - categorical_accuracy: 0.8712
# Epoch 42: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 568ms/step - loss: 0.3100 - categorical_accuracy: 0.8712 - val_loss: 1.2962 - val_categorical_accuracy: 0.6154
# Epoch 43/80
# 25/25 [==============================] - ETA: 0s - loss: 0.2666 - categorical_accuracy: 0.9056
# Epoch 43: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 564ms/step - loss: 0.2666 - categorical_accuracy: 0.9056 - val_loss: 3.0892 - val_categorical_accuracy: 0.5976
# Epoch 44/80
# 25/25 [==============================] - ETA: 0s - loss: 0.3246 - categorical_accuracy: 0.8801
# Epoch 44: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 15s 611ms/step - loss: 0.3246 - categorical_accuracy: 0.8801 - val_loss: 1.8909 - val_categorical_accuracy: 0.4793
# Epoch 45/80
# 25/25 [==============================] - ETA: 0s - loss: 0.2746 - categorical_accuracy: 0.8916
# Epoch 45: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 563ms/step - loss: 0.2746 - categorical_accuracy: 0.8916 - val_loss: 1.6678 - val_categorical_accuracy: 0.6095
# Epoch 46/80
# 25/25 [==============================] - ETA: 0s - loss: 0.2557 - categorical_accuracy: 0.9247
# Epoch 46: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 563ms/step - loss: 0.2557 - categorical_accuracy: 0.9247 - val_loss: 1.6068 - val_categorical_accuracy: 0.5680
# Epoch 47/80
# 25/25 [==============================] - ETA: 0s - loss: 0.2202 - categorical_accuracy: 0.9094
# Epoch 47: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 560ms/step - loss: 0.2202 - categorical_accuracy: 0.9094 - val_loss: 1.0904 - val_categorical_accuracy: 0.6450
# Epoch 48/80
# 25/25 [==============================] - ETA: 0s - loss: 0.3028 - categorical_accuracy: 0.8890
# Epoch 48: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 561ms/step - loss: 0.3028 - categorical_accuracy: 0.8890 - val_loss: 2.2465 - val_categorical_accuracy: 0.4734
# Epoch 49/80
# 25/25 [==============================] - ETA: 0s - loss: 0.2717 - categorical_accuracy: 0.8967
# Epoch 49: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 562ms/step - loss: 0.2717 - categorical_accuracy: 0.8967 - val_loss: 1.6396 - val_categorical_accuracy: 0.6154
# Epoch 50/80
# 25/25 [==============================] - ETA: 0s - loss: 0.2122 - categorical_accuracy: 0.9273
# Epoch 50: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 566ms/step - loss: 0.2122 - categorical_accuracy: 0.9273 - val_loss: 1.5516 - val_categorical_accuracy: 0.5799
# Epoch 51/80
# 25/25 [==============================] - ETA: 0s - loss: 0.1512 - categorical_accuracy: 0.9439
# Epoch 51: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 566ms/step - loss: 0.1512 - categorical_accuracy: 0.9439 - val_loss: 1.7212 - val_categorical_accuracy: 0.6095
# Epoch 52/80
# 25/25 [==============================] - ETA: 0s - loss: 0.1972 - categorical_accuracy: 0.9362
# Epoch 52: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 564ms/step - loss: 0.1972 - categorical_accuracy: 0.9362 - val_loss: 1.8998 - val_categorical_accuracy: 0.5385
# Epoch 53/80
# 25/25 [==============================] - ETA: 0s - loss: 0.1998 - categorical_accuracy: 0.9311
# Epoch 53: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 563ms/step - loss: 0.1998 - categorical_accuracy: 0.9311 - val_loss: 1.2423 - val_categorical_accuracy: 0.6450
# Epoch 54/80
# 25/25 [==============================] - ETA: 0s - loss: 0.2074 - categorical_accuracy: 0.9209
# Epoch 54: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 564ms/step - loss: 0.2074 - categorical_accuracy: 0.9209 - val_loss: 2.5475 - val_categorical_accuracy: 0.5030
# Epoch 55/80
# 25/25 [==============================] - ETA: 0s - loss: 0.2296 - categorical_accuracy: 0.9158
# Epoch 55: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 563ms/step - loss: 0.2296 - categorical_accuracy: 0.9158 - val_loss: 1.3583 - val_categorical_accuracy: 0.5976
# Epoch 56/80
# 25/25 [==============================] - ETA: 0s - loss: 0.1854 - categorical_accuracy: 0.9401
# Epoch 56: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 15s 585ms/step - loss: 0.1854 - categorical_accuracy: 0.9401 - val_loss: 1.8051 - val_categorical_accuracy: 0.6272
# Epoch 57/80
# 25/25 [==============================] - ETA: 0s - loss: 0.2413 - categorical_accuracy: 0.9120
# Epoch 57: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 566ms/step - loss: 0.2413 - categorical_accuracy: 0.9120 - val_loss: 1.8564 - val_categorical_accuracy: 0.6391
# Epoch 58/80
# 25/25 [==============================] - ETA: 0s - loss: 0.1847 - categorical_accuracy: 0.9401
# Epoch 58: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 15s 619ms/step - loss: 0.1847 - categorical_accuracy: 0.9401 - val_loss: 1.5707 - val_categorical_accuracy: 0.6450
# Epoch 59/80
# 25/25 [==============================] - ETA: 0s - loss: 0.1583 - categorical_accuracy: 0.9477
# Epoch 59: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 573ms/step - loss: 0.1583 - categorical_accuracy: 0.9477 - val_loss: 1.6706 - val_categorical_accuracy: 0.5444
# Epoch 60/80
# 25/25 [==============================] - ETA: 0s - loss: 0.1165 - categorical_accuracy: 0.9617
# Epoch 60: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 569ms/step - loss: 0.1165 - categorical_accuracy: 0.9617 - val_loss: 1.5809 - val_categorical_accuracy: 0.5799
# Epoch 61/80
# 25/25 [==============================] - ETA: 0s - loss: 0.1365 - categorical_accuracy: 0.9566
# Epoch 61: val_categorical_accuracy did not improve from 0.66864
# 25/25 [==============================] - 14s 576ms/step - loss: 0.1365 - categorical_accuracy: 0.9566 - val_loss: 2.2484 - val_categorical_accuracy: 0.5562
# Epoch 62/80
# 25/25 [==============================] - ETA: 0s - loss: 0.1298 - categorical_accuracy: 0.9452
# Epoch 62: val_categorical_accuracy improved from 0.66864 to 0.67456, saving model to /content/drive/MyDrive/Car Damage Classification/vgg16/checkpoint.hdf5
# 25/25 [==============================] - 16s 645ms/step - loss: 0.1298 - categorical_accuracy: 0.9452 - val_loss: 1.3813 - val_categorical_accuracy: 0.6746
# Epoch 63/80
# 25/25 [==============================] - ETA: 0s - loss: 0.1529 - categorical_accuracy: 0.9464
# Epoch 63: val_categorical_accuracy did not improve from 0.67456
# 25/25 [==============================] - 15s 585ms/step - loss: 0.1529 - categorical_accuracy: 0.9464 - val_loss: 1.6039 - val_categorical_accuracy: 0.5799
# Epoch 64/80
# 25/25 [==============================] - ETA: 0s - loss: 0.1190 - categorical_accuracy: 0.9554
# Epoch 64: val_categorical_accuracy did not improve from 0.67456
# 25/25 [==============================] - 14s 571ms/step - loss: 0.1190 - categorical_accuracy: 0.9554 - val_loss: 1.5549 - val_categorical_accuracy: 0.6154
# Epoch 65/80
# 25/25 [==============================] - ETA: 0s - loss: 0.1493 - categorical_accuracy: 0.9528
# Epoch 65: val_categorical_accuracy did not improve from 0.67456
# 25/25 [==============================] - 14s 574ms/step - loss: 0.1493 - categorical_accuracy: 0.9528 - val_loss: 1.6336 - val_categorical_accuracy: 0.6154
# Epoch 66/80
# 25/25 [==============================] - ETA: 0s - loss: 0.1364 - categorical_accuracy: 0.9566
# Epoch 66: val_categorical_accuracy did not improve from 0.67456
# 25/25 [==============================] - 14s 566ms/step - loss: 0.1364 - categorical_accuracy: 0.9566 - val_loss: 1.7822 - val_categorical_accuracy: 0.5680
# Epoch 67/80
# 25/25 [==============================] - ETA: 0s - loss: 0.1263 - categorical_accuracy: 0.9592
# Epoch 67: val_categorical_accuracy did not improve from 0.67456
# 25/25 [==============================] - 14s 563ms/step - loss: 0.1263 - categorical_accuracy: 0.9592 - val_loss: 1.4537 - val_categorical_accuracy: 0.6272
# Epoch 68/80
# 25/25 [==============================] - ETA: 0s - loss: 0.1093 - categorical_accuracy: 0.9656
# Epoch 68: val_categorical_accuracy did not improve from 0.67456
# 25/25 [==============================] - 14s 566ms/step - loss: 0.1093 - categorical_accuracy: 0.9656 - val_loss: 2.1820 - val_categorical_accuracy: 0.5858
# Epoch 69/80
# 25/25 [==============================] - ETA: 0s - loss: 0.0910 - categorical_accuracy: 0.9707
# Epoch 69: val_categorical_accuracy did not improve from 0.67456
# 25/25 [==============================] - 15s 599ms/step - loss: 0.0910 - categorical_accuracy: 0.9707 - val_loss: 2.3401 - val_categorical_accuracy: 0.5858
# Epoch 70/80
# 25/25 [==============================] - ETA: 0s - loss: 0.1158 - categorical_accuracy: 0.9528
# Epoch 70: val_categorical_accuracy did not improve from 0.67456
# 25/25 [==============================] - 14s 576ms/step - loss: 0.1158 - categorical_accuracy: 0.9528 - val_loss: 2.2238 - val_categorical_accuracy: 0.6095
# Epoch 71/80
# 25/25 [==============================] - ETA: 0s - loss: 0.1396 - categorical_accuracy: 0.9554
# Epoch 71: val_categorical_accuracy did not improve from 0.67456
# 25/25 [==============================] - 16s 621ms/step - loss: 0.1396 - categorical_accuracy: 0.9554 - val_loss: 1.7172 - val_categorical_accuracy: 0.6095
# Epoch 72/80
# 25/25 [==============================] - ETA: 0s - loss: 0.1498 - categorical_accuracy: 0.9503
# Epoch 72: val_categorical_accuracy did not improve from 0.67456
# 25/25 [==============================] - 14s 560ms/step - loss: 0.1498 - categorical_accuracy: 0.9503 - val_loss: 3.0823 - val_categorical_accuracy: 0.5858
# Epoch 73/80
# 25/25 [==============================] - ETA: 0s - loss: 0.1237 - categorical_accuracy: 0.9554
# Epoch 73: val_categorical_accuracy did not improve from 0.67456
# 25/25 [==============================] - 14s 564ms/step - loss: 0.1237 - categorical_accuracy: 0.9554 - val_loss: 1.5215 - val_categorical_accuracy: 0.6154
# Epoch 74/80
# 25/25 [==============================] - ETA: 0s - loss: 0.1410 - categorical_accuracy: 0.9528
# Epoch 74: val_categorical_accuracy did not improve from 0.67456
# 25/25 [==============================] - 14s 580ms/step - loss: 0.1410 - categorical_accuracy: 0.9528 - val_loss: 1.3601 - val_categorical_accuracy: 0.5917
# Epoch 75/80
# 25/25 [==============================] - ETA: 0s - loss: 0.1079 - categorical_accuracy: 0.9643
# Epoch 75: val_categorical_accuracy did not improve from 0.67456
# 25/25 [==============================] - 14s 562ms/step - loss: 0.1079 - categorical_accuracy: 0.9643 - val_loss: 1.8008 - val_categorical_accuracy: 0.6272
# Epoch 76/80
# 25/25 [==============================] - ETA: 0s - loss: 0.0842 - categorical_accuracy: 0.9719
# Epoch 76: val_categorical_accuracy did not improve from 0.67456
# 25/25 [==============================] - 14s 565ms/step - loss: 0.0842 - categorical_accuracy: 0.9719 - val_loss: 1.5563 - val_categorical_accuracy: 0.6213
# Epoch 77/80
# 25/25 [==============================] - ETA: 0s - loss: 0.1198 - categorical_accuracy: 0.9566
# Epoch 77: val_categorical_accuracy did not improve from 0.67456
# 25/25 [==============================] - 14s 557ms/step - loss: 0.1198 - categorical_accuracy: 0.9566 - val_loss: 1.4304 - val_categorical_accuracy: 0.6331
# Epoch 78/80
# 25/25 [==============================] - ETA: 0s - loss: 0.1373 - categorical_accuracy: 0.9541
# Epoch 78: val_categorical_accuracy did not improve from 0.67456
# 25/25 [==============================] - 14s 559ms/step - loss: 0.1373 - categorical_accuracy: 0.9541 - val_loss: 3.8852 - val_categorical_accuracy: 0.5740
# Epoch 79/80
# 25/25 [==============================] - ETA: 0s - loss: 0.1594 - categorical_accuracy: 0.9401
# Epoch 79: val_categorical_accuracy did not improve from 0.67456
# 25/25 [==============================] - 14s 561ms/step - loss: 0.1594 - categorical_accuracy: 0.9401 - val_loss: 1.7935 - val_categorical_accuracy: 0.5917
# Epoch 80/80
# 25/25 [==============================] - ETA: 0s - loss: 0.1074 - categorical_accuracy: 0.9707
# Epoch 80: val_categorical_accuracy did not improve from 0.67456
# 25/25 [==============================] - 14s 564ms/step - loss: 0.1074 - categorical_accuracy: 0.9707 - val_loss: 1.5801 - val_categorical_accuracy: 0.6095

# %%
model.save('/content/drive/MyDrive/Car Damage Classification/vgg16/h5 files/gray/model9.h5')

# %% [markdown]
# # Testing Model

# %%
model.save('/content/drive/MyDrive/Car Damage Classification/my_model')
results = model.evaluate(test_set,batch_size=32)
accuracy = results[1]
predict_labels=model.predict(test_set,batch_size=batchSize)
test_labels=test_set.classes
print(accuracy)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# 7/7 [==============================] - 1s 131ms/step - loss: 1.7491 - categorical_accuracy: 0.6000
# 7/7 [==============================] - 1s 134ms/step
# 0.6000000238418579

# %%
print(test_labels)
print(predict_labels.argmax(axis=1))
from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(test_labels, predict_labels.argmax(axis=1), target_names=['minor', 'moderate', 'severe']))
confusion = confusion_matrix(test_labels, predict_labels.argmax(axis=1))
print('Confusion Matrix\n')
print(confusion)
